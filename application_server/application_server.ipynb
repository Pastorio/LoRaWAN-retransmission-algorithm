# %%
# !pip install paho-mqtt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: paho-mqtt in /usr/local/lib/python3.7/dist-packages (1.6.1)

# %%
# Libs
import base64
import os, sys, logging, time
import paho.mqtt.client as mqtt
import json
import csv
from datetime import datetime
import codecs

import pandas as pd
import numpy as np

# %%
# Parameters - CHANGE FOR YOUR APPLICATION
User = "app-tcc-tolerancia-a-falhas@ttn" #Application_id@ttn
Password = "NNSXS.DV5HGU3NIIGDTQB5VP6KLCZ46LPBZ36G2Z446CQ.TWRPLH7ZUH4DWMRNVRURRFHKOHVNEPGSCAROOXHPRHMNOLPTZN4Q" # Token generated in the things stack
Server = "au1.cloud.thethings.network" # Network server
DEVID = "ttgo-app-tolerante-a-falhas" # dev_id of device application

# Global
topic = "v3/"+ User + "/devices/"+DEVID+"/down/push"
message = '{"downlinks":[{"f_port": 1,"frm_payload":"vu8=","priority": "NORMAL"}]}'

list_of_fcnt = []
fcnt_retrans_list = []
fcnt_retrans_request = []
count_next_retrans = 0

# Used to compare algorithms, store json data
list_cr_lorawan = []
list_alr_lorawan = []

# Used to store data received, better use just list_alr_lorawan if want to store data
df_fcnts = pd.DataFrame(columns=['time', 'fcnt', 'fcnt_raw'])
df_fcnt_retrans_request = pd.DataFrame(columns=['retransmission', 'fcnt'])

# %%
def on_connect(mqttc, obj, flags, rc):
  global count_retransmission
  global pkt_not_received
  count_retransmission = 0
  pkt_not_received = []
  print("Connection: rc = " + str(rc))

def on_subscribe(mqttc, obj, mid, granted_qos):
	print("Subscribe: " + str(mid) + " " + str(granted_qos))

def on_log(mqttc, obj, level, string):
	print("Log: "+ string)
	logging_level = mqtt.LOGGING_LEVEL[level]
	logging.log(logging_level, string)

def on_publish(client,userdata,result):
  print("client:",client," userdata:",userdata," result:",result)
  print("Published \n")
  pass

# %%
def on_message(mqttc, obj, msg):
  print("Message: " + msg.topic + " " + str(msg.qos)))

  payload = json.loads(msg.payload)
  print("Payload: ", payload)

  if(payload['end_device_ids']['device_id'] == 'ttgo-crlorawan'):
    print('-- CR LORAWAN ', payload)
    if ("uplink_message" in payload) and ("f_cnt" in payload["uplink_message"]):
      print('---- CR LORAWAN - SAVE - FCNT: ', payload["uplink_message"]["f_cnt"])
      list_cr_lorawan.append(payload)
    return

  print('-- ALR LORAWAN ', payload)
  if ("uplink_message" in payload) and ("f_cnt" in payload["uplink_message"]):
    
    print('---- ALR LORAWAN - SAVE - FCNT: ', payload["uplink_message"]["f_cnt"])
    list_alr_lorawan.append(payload)

    global count_retransmission
    global pkt_not_received
    global count_next_retrans
    global fcnt_retrans_request

    global df_fcnts # For Analysis
    global df_fcnt_retrans_request # For Analysis

    fcnt = payload["uplink_message"]["f_cnt"]

    list_of_fcnt.append(payload["uplink_message"]["f_cnt"])
    list_of_fcnt.sort()
    
    all_list = list(range((list_of_fcnt[0]), list_of_fcnt[-1]+1))
    fcnt_retrans_list = list(set(all_list) - set(list_of_fcnt))

    print("-- uplink_message received - FCNT: ", fcnt)
    print("uplink_message: ", payload["uplink_message"])
    print("list_of_fcnt: ", list_of_fcnt)
    print("fcnt_retrans_list: ", fcnt_retrans_list)

    if "decoded_payload" in payload["uplink_message"]:
      decoded_payload = payload["uplink_message"]["decoded_payload"]
      fcnt_raw = decoded_payload['fcnt']
      df_fcnts = df_fcnts.append({'time':payload["received_at"], 'fcnt':fcnt, 'fcnt_raw':fcnt_raw},ignore_index=True) # For Analysis

      if (len(fcnt_retrans_list)!=0) and (fcnt_raw in fcnt_retrans_list):
        fcnt_retrans_list.remove(fcnt_raw)
        list_of_fcnt.insert(0, fcnt_raw)

      print("--- decoded_payload: ", decoded_payload, " fcnt_retransmission: ", fcnt_raw)

    msg_downling = ''
    if len(fcnt_retrans_list) > 0 and count_next_retrans == 0:
      fcnt_retrans_list.sort()
      num_package_retrans = 1 # Retransmission factor N
      count_next_retrans = 2 # Dalay for retransmission request

      if len(fcnt_retrans_list) >= num_package_retrans: 
        for retranmite_fcnt in fcnt_retrans_list[0:num_package_retrans]:
          fcnt_retrans_request.append(retranmite_fcnt)
          df_fcnt_retrans_request = df_fcnt_retrans_request.append({'retransmission':0, 'fcnt':retranmite_fcnt},ignore_index=True)
          
          retranmite_fcnt = str(hex(retranmite_fcnt)[2:])
          retranmite_fcnt = retranmite_fcnt.zfill(4)
          msg_downling = msg_downling + retranmite_fcnt
          
      base64_message = codecs.encode(codecs.decode(msg_downling, 'hex'), 'base64').decode().replace("\n", "")
      
      message = '{"downlinks":[{"f_port": 1,"frm_payload":"'+base64_message+'","priority": "NORMAL"}]}'
      print("-- Try pub ", message, ' msg_downling ',msg_downling)
      mqttc.publish(topic,message)

      count_retransmission = count_retransmission + 1
    
    print('----count_retransmission: ', count_retransmission, ' msg_downling: ', msg_downling, ' count_next_retrans: ', count_next_retrans, ' fcnt_retransmited: ', fcnt_retrans_request)
    
    if count_next_retrans != 0:
      count_next_retrans = count_next_retrans-1

# %%
def main():
    
  print("Initialization MQTT Client")
  mqttc = mqtt.Client()

  print("Update MQTT Modules callback")
  mqttc.on_connect = on_connect
  mqttc.on_subscribe = on_subscribe
  mqttc.on_message = on_message
  mqttc.on_publish = on_publish

  mqttc.username_pw_set(User, Password) # Setup authentication from settings above
  mqttc.tls_set()	# default certification authority of the system

  mqttc.connect(Server, 8883, 60)

  print("Subscribe")
  mqttc.subscribe("#", 0)	# all device uplinks

  print("And run forever")
  try:    
    while True:
      mqttc.loop(10) 	# seconds timeout / blocking time
      print(".", end="", flush=True)	# feedback to the user that something is actually happening
      
  except KeyboardInterrupt:
    print("Exit")
    sys.exit(0)

if __name__ == '__main__':
  main()
# Out:
# Init mqtt client
# Assign callbacks
# Subscribe
# And run forever
# .
# Connect: rc = 0
# .
# Subscribe: 1 (0,)
# ............
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D9473'}, 'correlation_ids': ['as:up:01G485BP7WJE18PYAEM37SX04H', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485BMF79A3K77ET245XG223', 'ns:uplink:01G485BMF8VWPMTKW7N6HNVS5D', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485BMF8FYDNHC6K94DYQBTA', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485BP7WV57JV48244NS6TVC'], 'received_at': '2022-05-29T15:01:10.524549104Z', 'join_accept': {'session_key_id': 'AYEQVdHvIJCBnwKVnHQB0g==', 'received_at': '2022-05-29T15:01:08.712564097Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D9473'}, 'correlation_ids': ['as:up:01G485BP7WJE18PYAEM37SX04H', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485BMF79A3K77ET245XG223', 'ns:uplink:01G485BMF8VWPMTKW7N6HNVS5D', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485BMF8FYDNHC6K94DYQBTA', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485BP7WV57JV48244NS6TVC'], 'received_at': '2022-05-29T15:01:10.524549104Z', 'join_accept': {'session_key_id': 'AYEQVdHvIJCBnwKVnHQB0g==', 'received_at': '2022-05-29T15:01:08.712564097Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DB26E'}, 'correlation_ids': ['as:up:01G485C71TJQ3BDHJCP7RRG91B', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485C58FS6S915121PMBTJP2', 'ns:uplink:01G485C58G0HYBEF1B949QKJE7', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485C58GJC846SJ5FDZ1D27Z', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485C71SQE6314XAE3VMBPHW'], 'received_at': '2022-05-29T15:01:27.738392392Z', 'join_accept': {'session_key_id': 'AYEQVhUUe1Zg723WopP3nA==', 'received_at': '2022-05-29T15:01:25.904554252Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DB26E'}, 'correlation_ids': ['as:up:01G485C71TJQ3BDHJCP7RRG91B', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485C58FS6S915121PMBTJP2', 'ns:uplink:01G485C58G0HYBEF1B949QKJE7', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485C58GJC846SJ5FDZ1D27Z', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485C71SQE6314XAE3VMBPHW'], 'received_at': '2022-05-29T15:01:27.738392392Z', 'join_accept': {'session_key_id': 'AYEQVhUUe1Zg723WopP3nA==', 'received_at': '2022-05-29T15:01:25.904554252Z'}}
# ....
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DA59E'}, 'correlation_ids': ['as:up:01G485CPT0HH3ZD2BZ55BX6KAC', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485CN16X82TF9ZC58ZQET3P', 'ns:uplink:01G485CN16H1V1T9V8BA6TCW1B', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485CN16KNZDB8SGW0P4VW64', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485CPT07DHAVCR5F788XFGF'], 'received_at': '2022-05-29T15:01:43.872858253Z', 'join_accept': {'session_key_id': 'AYEQVlQtRmU6UA2K4Y/qfw==', 'received_at': '2022-05-29T15:01:42.054949387Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DA59E'}, 'correlation_ids': ['as:up:01G485CPT0HH3ZD2BZ55BX6KAC', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485CN16X82TF9ZC58ZQET3P', 'ns:uplink:01G485CN16H1V1T9V8BA6TCW1B', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485CN16KNZDB8SGW0P4VW64', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485CPT07DHAVCR5F788XFGF'], 'received_at': '2022-05-29T15:01:43.872858253Z', 'join_accept': {'session_key_id': 'AYEQVlQtRmU6UA2K4Y/qfw==', 'received_at': '2022-05-29T15:01:42.054949387Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D5FE2'}, 'correlation_ids': ['as:up:01G485D4KX2HEVQ9BMZV033M97', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485D2VCXFD7KK6RE82BXBKM', 'ns:uplink:01G485D2VDDCZMK9DP9TJXTG4D', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485D2VDA3C90ZZD1SD1FN7G', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485D4KWTGZ9JE4X9D0ZQK89'], 'received_at': '2022-05-29T15:01:58.013214195Z', 'join_accept': {'session_key_id': 'AYEQVot1sXq1iz+bQZEc/Q==', 'received_at': '2022-05-29T15:01:56.205732764Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D5FE2'}, 'correlation_ids': ['as:up:01G485D4KX2HEVQ9BMZV033M97', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485D2VCXFD7KK6RE82BXBKM', 'ns:uplink:01G485D2VDDCZMK9DP9TJXTG4D', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485D2VDA3C90ZZD1SD1FN7G', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485D4KWTGZ9JE4X9D0ZQK89'], 'received_at': '2022-05-29T15:01:58.013214195Z', 'join_accept': {'session_key_id': 'AYEQVot1sXq1iz+bQZEc/Q==', 'received_at': '2022-05-29T15:01:56.205732764Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DA34A'}, 'correlation_ids': ['as:up:01G485DKWXD3Q44HRVHQSG4RFM', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485DJ4359X76BE5NSZ62G42', 'ns:uplink:01G485DJ44C8ACZAQ4J7G4PH8B', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485DJ44FAB7FGDRSCZVSBJT', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485DKWW8REVKVQWKZDDPP9F'], 'received_at': '2022-05-29T15:02:13.661498254Z', 'join_accept': {'session_key_id': 'AYEQVsiJt6+07rVcdBTuQQ==', 'received_at': '2022-05-29T15:02:11.844458264Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DA34A'}, 'correlation_ids': ['as:up:01G485DKWXD3Q44HRVHQSG4RFM', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485DJ4359X76BE5NSZ62G42', 'ns:uplink:01G485DJ44C8ACZAQ4J7G4PH8B', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485DJ44FAB7FGDRSCZVSBJT', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485DKWW8REVKVQWKZDDPP9F'], 'received_at': '2022-05-29T15:02:13.661498254Z', 'join_accept': {'session_key_id': 'AYEQVsiJt6+07rVcdBTuQQ==', 'received_at': '2022-05-29T15:02:11.844458264Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D76D0'}, 'correlation_ids': ['as:up:01G485E4PYYEHWT6TQEN3JW38C', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485E2Y5T6SD0F1N7H4FZ668', 'ns:uplink:01G485E2Y6VEX2AJHJA53E627F', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485E2Y6YWVTX4ZBVTXAD7XD', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485E4PYZPEVGTF5CV8W8XGK'], 'received_at': '2022-05-29T15:02:30.878660943Z', 'join_accept': {'session_key_id': 'AYEQVwvNoMNfk86OuP8T7A==', 'received_at': '2022-05-29T15:02:29.062543789Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D76D0'}, 'correlation_ids': ['as:up:01G485E4PYYEHWT6TQEN3JW38C', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485E2Y5T6SD0F1N7H4FZ668', 'ns:uplink:01G485E2Y6VEX2AJHJA53E627F', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485E2Y6YWVTX4ZBVTXAD7XD', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485E4PYZPEVGTF5CV8W8XGK'], 'received_at': '2022-05-29T15:02:30.878660943Z', 'join_accept': {'session_key_id': 'AYEQVwvNoMNfk86OuP8T7A==', 'received_at': '2022-05-29T15:02:29.062543789Z'}}
# ....
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D4896'}, 'correlation_ids': ['as:up:01G485ENDYHDR2H95NW69TJWNE', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485EKNGHAMCGYH36A02FYGP', 'ns:uplink:01G485EKNH6R7JX7W4PBTQGJFT', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485EKNHFGSAFBWD3RD5HW48', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485ENDYYV0KMD16N88T407D'], 'received_at': '2022-05-29T15:02:47.999079916Z', 'join_accept': {'session_key_id': 'AYEQV061sXWnCW1KcdufTA==', 'received_at': '2022-05-29T15:02:46.193250427Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D4896'}, 'correlation_ids': ['as:up:01G485ENDYHDR2H95NW69TJWNE', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485EKNGHAMCGYH36A02FYGP', 'ns:uplink:01G485EKNH6R7JX7W4PBTQGJFT', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485EKNHFGSAFBWD3RD5HW48', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485ENDYYV0KMD16N88T407D'], 'received_at': '2022-05-29T15:02:47.999079916Z', 'join_accept': {'session_key_id': 'AYEQV061sXWnCW1KcdufTA==', 'received_at': '2022-05-29T15:02:46.193250427Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DEAE7'}, 'correlation_ids': ['as:up:01G485F3TM57R2H8QQBHN86VMZ', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485F224MN7J8GE97KA6E1DN', 'ns:uplink:01G485F225RWMRJXN7Q3CP7B4B', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485F224Y9V8WMG4SH20Q4AY', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485F3TKHW3F74AJXXEDBP8Q'], 'received_at': '2022-05-29T15:03:02.740151233Z', 'join_accept': {'session_key_id': 'AYEQV4hIQura9nE0NSXuDw==', 'received_at': '2022-05-29T15:03:00.933107568Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DEAE7'}, 'correlation_ids': ['as:up:01G485F3TM57R2H8QQBHN86VMZ', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485F224MN7J8GE97KA6E1DN', 'ns:uplink:01G485F225RWMRJXN7Q3CP7B4B', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485F224Y9V8WMG4SH20Q4AY', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485F3TKHW3F74AJXXEDBP8Q'], 'received_at': '2022-05-29T15:03:02.740151233Z', 'join_accept': {'session_key_id': 'AYEQV4hIQura9nE0NSXuDw==', 'received_at': '2022-05-29T15:03:00.933107568Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DC4C7'}, 'correlation_ids': ['as:up:01G485FJYN39GXS5EZWH13Y4PR', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485FH62KNH50RW3VPWSGWXN', 'ns:uplink:01G485FH631T5SXSE6PQ71JPG9', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485FH63S140B9YW2SQEZPR0', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485FJYNV0BGT0G1CZ24JF9Y'], 'received_at': '2022-05-29T15:03:18.230063607Z', 'join_accept': {'session_key_id': 'AYEQV8THzz742WCc8Nfu1w==', 'received_at': '2022-05-29T15:03:16.419383531Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DC4C7'}, 'correlation_ids': ['as:up:01G485FJYN39GXS5EZWH13Y4PR', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485FH62KNH50RW3VPWSGWXN', 'ns:uplink:01G485FH631T5SXSE6PQ71JPG9', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485FH63S140B9YW2SQEZPR0', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485FJYNV0BGT0G1CZ24JF9Y'], 'received_at': '2022-05-29T15:03:18.230063607Z', 'join_accept': {'session_key_id': 'AYEQV8THzz742WCc8Nfu1w==', 'received_at': '2022-05-29T15:03:16.419383531Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D02D0'}, 'correlation_ids': ['as:up:01G485G21JMAZK6XZFWXK5GHVS', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485G08ZP515GSR737125QVV', 'ns:uplink:01G485G08Z50XTKVVSK0GPV3AN', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485G08ZZF88X27G0XEADMXN', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485G21HM32JJJE0SFME4Y54'], 'received_at': '2022-05-29T15:03:33.682791019Z', 'join_accept': {'session_key_id': 'AYEQWAEyWcj0h0t24pFyYA==', 'received_at': '2022-05-29T15:03:31.871906076Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D02D0'}, 'correlation_ids': ['as:up:01G485G21JMAZK6XZFWXK5GHVS', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485G08ZP515GSR737125QVV', 'ns:uplink:01G485G08Z50XTKVVSK0GPV3AN', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485G08ZZF88X27G0XEADMXN', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485G21HM32JJJE0SFME4Y54'], 'received_at': '2022-05-29T15:03:33.682791019Z', 'join_accept': {'session_key_id': 'AYEQWAEyWcj0h0t24pFyYA==', 'received_at': '2022-05-29T15:03:31.871906076Z'}}
# ....
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D7751'}, 'correlation_ids': ['as:up:01G485GFWTWB24Y7G2ENQDTB4V', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485GE3WSTG6N0Y3HF4NJA54', 'ns:uplink:01G485GE3WCMF5PJV18BVY5NZ8', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485GE3WB04PDVSE8VPTVJPS', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485GFWS5Y3CENP85Z8C3AT2'], 'received_at': '2022-05-29T15:03:47.866330677Z', 'join_accept': {'session_key_id': 'AYEQWDiEAvZ42b6j8W5RFw==', 'received_at': '2022-05-29T15:03:46.044805652Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D7751'}, 'correlation_ids': ['as:up:01G485GFWTWB24Y7G2ENQDTB4V', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485GE3WSTG6N0Y3HF4NJA54', 'ns:uplink:01G485GE3WCMF5PJV18BVY5NZ8', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485GE3WB04PDVSE8VPTVJPS', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485GFWS5Y3CENP85Z8C3AT2'], 'received_at': '2022-05-29T15:03:47.866330677Z', 'join_accept': {'session_key_id': 'AYEQWDiEAvZ42b6j8W5RFw==', 'received_at': '2022-05-29T15:03:46.044805652Z'}}
# ...
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DC51E'}, 'correlation_ids': ['as:up:01G485HCTMPFENFN8VVGKSFJKY', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485HB1QBS0Q2GZ1YBY3TGJM', 'ns:uplink:01G485HB1RPC8D0CMZFJ9ZQJ2J', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485HB1R3B74K6YJH2ZPV1WN', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485HCTM97F3F9JWSY8TG92W'], 'received_at': '2022-05-29T15:04:17.492489504Z', 'join_accept': {'session_key_id': 'AYEQWKxA/YdZEEVvAwMdIA==', 'received_at': '2022-05-29T15:04:15.672901122Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DC51E'}, 'correlation_ids': ['as:up:01G485HCTMPFENFN8VVGKSFJKY', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485HB1QBS0Q2GZ1YBY3TGJM', 'ns:uplink:01G485HB1RPC8D0CMZFJ9ZQJ2J', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485HB1R3B74K6YJH2ZPV1WN', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485HCTM97F3F9JWSY8TG92W'], 'received_at': '2022-05-29T15:04:17.492489504Z', 'join_accept': {'session_key_id': 'AYEQWKxA/YdZEEVvAwMdIA==', 'received_at': '2022-05-29T15:04:15.672901122Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DB5E2'}, 'correlation_ids': ['as:up:01G485HTQEK0DV8Q7PQGMF1172', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485HRYZZZZBKV1Q4FPS9GAM', 'ns:uplink:01G485HRYZPVN4HJK5WYVPQ3R8', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485HRYZESKETHETWSZZ2RSC', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485HTQDZF0WWRYEW9HYQ7E8'], 'received_at': '2022-05-29T15:04:31.726332455Z', 'join_accept': {'session_key_id': 'AYEQWOPngegj6u7EaQ1Wfg==', 'received_at': '2022-05-29T15:04:29.919916967Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DB5E2'}, 'correlation_ids': ['as:up:01G485HTQEK0DV8Q7PQGMF1172', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485HRYZZZZBKV1Q4FPS9GAM', 'ns:uplink:01G485HRYZPVN4HJK5WYVPQ3R8', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485HRYZESKETHETWSZZ2RSC', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485HTQDZF0WWRYEW9HYQ7E8'], 'received_at': '2022-05-29T15:04:31.726332455Z', 'join_accept': {'session_key_id': 'AYEQWOPngegj6u7EaQ1Wfg==', 'received_at': '2022-05-29T15:04:29.919916967Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D4567'}, 'correlation_ids': ['as:up:01G485J9HHDQ3A94ATRZTKCD3S', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485J7RYCVSTA1MBD5DF1AN4', 'ns:uplink:01G485J7RZDEA2DSCTQRJ99NXA', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485J7RYJSE7SYWFTQ0PVY78', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485J9HHS9VYVHAM3JXK2BVE'], 'received_at': '2022-05-29T15:04:46.897872250Z', 'join_accept': {'session_key_id': 'AYEQWR8ilqloL8o+DrfeBQ==', 'received_at': '2022-05-29T15:04:45.087019740Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D4567'}, 'correlation_ids': ['as:up:01G485J9HHDQ3A94ATRZTKCD3S', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485J7RYCVSTA1MBD5DF1AN4', 'ns:uplink:01G485J7RZDEA2DSCTQRJ99NXA', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485J7RYJSE7SYWFTQ0PVY78', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485J9HHS9VYVHAM3JXK2BVE'], 'received_at': '2022-05-29T15:04:46.897872250Z', 'join_accept': {'session_key_id': 'AYEQWR8ilqloL8o+DrfeBQ==', 'received_at': '2022-05-29T15:04:45.087019740Z'}}
# ....
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D9E49'}, 'correlation_ids': ['as:up:01G485JT41BY8ZT2PYR5NGWR3R', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485JRBF51PS9HBEXBNK38MP', 'ns:uplink:01G485JRBFW5CD4QJKJX8Q0PH5', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485JRBF4X6DAQJ7TWFR3W13', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485JT41N8YHWPTJV44V44N6'], 'received_at': '2022-05-29T15:05:03.874045406Z', 'join_accept': {'session_key_id': 'AYEQWWF1HzqYKfPi2j+HFQ==', 'received_at': '2022-05-29T15:05:02.063995872Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D9E49'}, 'correlation_ids': ['as:up:01G485JT41BY8ZT2PYR5NGWR3R', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485JRBF51PS9HBEXBNK38MP', 'ns:uplink:01G485JRBFW5CD4QJKJX8Q0PH5', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485JRBF4X6DAQJ7TWFR3W13', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485JT41N8YHWPTJV44V44N6'], 'received_at': '2022-05-29T15:05:03.874045406Z', 'join_accept': {'session_key_id': 'AYEQWWF1HzqYKfPi2j+HFQ==', 'received_at': '2022-05-29T15:05:02.063995872Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DB450'}, 'correlation_ids': ['as:up:01G485KA9TXDQFVY8FGZ4NH6SY', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485K8H7S46EDT7BRV4EDZR3', 'ns:uplink:01G485K8H7T9ZVB9KQ2SK9RRDK', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485K8H7TKRNZJJS5W3AH1RT', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485KA9TFM2GBMP8D3WRG2WX'], 'received_at': '2022-05-29T15:05:20.442879590Z', 'join_accept': {'session_key_id': 'AYEQWaIrpSVLN8g0ggeh4g==', 'received_at': '2022-05-29T15:05:18.631706297Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DB450'}, 'correlation_ids': ['as:up:01G485KA9TXDQFVY8FGZ4NH6SY', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485K8H7S46EDT7BRV4EDZR3', 'ns:uplink:01G485K8H7T9ZVB9KQ2SK9RRDK', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485K8H7TKRNZJJS5W3AH1RT', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485KA9TFM2GBMP8D3WRG2WX'], 'received_at': '2022-05-29T15:05:20.442879590Z', 'join_accept': {'session_key_id': 'AYEQWaIrpSVLN8g0ggeh4g==', 'received_at': '2022-05-29T15:05:18.631706297Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DC5A7'}, 'correlation_ids': ['as:up:01G485KRR9Z3HXCXRSCKFZCATZ', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485KPZKDD9MEDBBAXYHA9AX', 'ns:uplink:01G485KPZMFNWWX7H1NJ1A8PF6', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485KPZMQ8K8JHC1548R77FQ', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485KRR90GZB7NKJCYN6KHMP'], 'received_at': '2022-05-29T15:05:35.242086291Z', 'join_accept': {'session_key_id': 'AYEQWdv5koEsfLctUysF2Q==', 'received_at': '2022-05-29T15:05:33.428270230Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DC5A7'}, 'correlation_ids': ['as:up:01G485KRR9Z3HXCXRSCKFZCATZ', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485KPZKDD9MEDBBAXYHA9AX', 'ns:uplink:01G485KPZMFNWWX7H1NJ1A8PF6', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485KPZMQ8K8JHC1548R77FQ', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485KRR90GZB7NKJCYN6KHMP'], 'received_at': '2022-05-29T15:05:35.242086291Z', 'join_accept': {'session_key_id': 'AYEQWdv5koEsfLctUysF2Q==', 'received_at': '2022-05-29T15:05:33.428270230Z'}}
# ......
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D45F8'}, 'correlation_ids': ['as:up:01G485MSHR9KE9C18SJ06VWZ68', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485MQS16J4GMD74FA4NBJNP', 'ns:uplink:01G485MQS4655634YYT4C05C51', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485MQS47T25CYEHGCANMGF5', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485MSHQ87YNP8JKE4GK71TM'], 'received_at': '2022-05-29T15:06:08.824280456Z', 'join_accept': {'session_key_id': 'AYEQWl8pEgtDeBnOiPcaww==', 'received_at': '2022-05-29T15:06:07.012271690Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D45F8'}, 'correlation_ids': ['as:up:01G485MSHR9KE9C18SJ06VWZ68', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485MQS16J4GMD74FA4NBJNP', 'ns:uplink:01G485MQS4655634YYT4C05C51', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485MQS47T25CYEHGCANMGF5', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485MSHQ87YNP8JKE4GK71TM'], 'received_at': '2022-05-29T15:06:08.824280456Z', 'join_accept': {'session_key_id': 'AYEQWl8pEgtDeBnOiPcaww==', 'received_at': '2022-05-29T15:06:07.012271690Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D619A'}, 'correlation_ids': ['as:up:01G485N6R5JG1N8P8DDPTH8TZ7', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485N4ZGRQZN3PDEQEG533Y0', 'ns:uplink:01G485N4ZH8N6K8MAB1RRF8DF2', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485N4ZHF4W4N6TYDW996J48', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485N6R4W94CX5TTQQTSHB2D'], 'received_at': '2022-05-29T15:06:22.341182036Z', 'join_accept': {'session_key_id': 'AYEQWpP2rvoDNsNMRRJT6Q==', 'received_at': '2022-05-29T15:06:20.529466164Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D619A'}, 'correlation_ids': ['as:up:01G485N6R5JG1N8P8DDPTH8TZ7', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485N4ZGRQZN3PDEQEG533Y0', 'ns:uplink:01G485N4ZH8N6K8MAB1RRF8DF2', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485N4ZHF4W4N6TYDW996J48', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485N6R4W94CX5TTQQTSHB2D'], 'received_at': '2022-05-29T15:06:22.341182036Z', 'join_accept': {'session_key_id': 'AYEQWpP2rvoDNsNMRRJT6Q==', 'received_at': '2022-05-29T15:06:20.529466164Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DE633'}, 'correlation_ids': ['as:up:01G485NPZWPZ4WRFTSY4S6J6Y4', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485NN793NSGF7D8EDFJDK79', 'ns:uplink:01G485NN7ATKGGGBJQ8G6N6XEV', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485NN7AGYJ5GZSAKWGXJ684', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485NPZVG99XD1ABCE51QN8W'], 'received_at': '2022-05-29T15:06:38.972781797Z', 'join_accept': {'session_key_id': 'AYEQWtTwh3DsIPSa3vLRzQ==', 'received_at': '2022-05-29T15:06:37.162575904Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DE633'}, 'correlation_ids': ['as:up:01G485NPZWPZ4WRFTSY4S6J6Y4', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485NN793NSGF7D8EDFJDK79', 'ns:uplink:01G485NN7ATKGGGBJQ8G6N6XEV', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485NN7AGYJ5GZSAKWGXJ684', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485NPZVG99XD1ABCE51QN8W'], 'received_at': '2022-05-29T15:06:38.972781797Z', 'join_accept': {'session_key_id': 'AYEQWtTwh3DsIPSa3vLRzQ==', 'received_at': '2022-05-29T15:06:37.162575904Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D6934'}, 'correlation_ids': ['as:up:01G485P42RFJ4F45T0WKWBATJB', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485P2A2VKRVQ5ZD8CSZ78K7', 'ns:uplink:01G485P2A3MRQ2R3FBJT6CCGMS', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485P2A3JVR7C66EA891KBP9', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485P42Q7560XX13CDPMJ68Q'], 'received_at': '2022-05-29T15:06:52.376314069Z', 'join_accept': {'session_key_id': 'AYEQWwlKI7mgZXiEuED7Tg==', 'received_at': '2022-05-29T15:06:50.563420267Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D6934'}, 'correlation_ids': ['as:up:01G485P42RFJ4F45T0WKWBATJB', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485P2A2VKRVQ5ZD8CSZ78K7', 'ns:uplink:01G485P2A3MRQ2R3FBJT6CCGMS', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485P2A3JVR7C66EA891KBP9', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485P42Q7560XX13CDPMJ68Q'], 'received_at': '2022-05-29T15:06:52.376314069Z', 'join_accept': {'session_key_id': 'AYEQWwlKI7mgZXiEuED7Tg==', 'received_at': '2022-05-29T15:06:50.563420267Z'}}
# ......
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DDDBE'}, 'correlation_ids': ['as:up:01G485Q2JW18HTGBR8DGHEWWKP', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485Q0TC1ZC7NZBZAY38FVMQ', 'ns:uplink:01G485Q0TDGK979WH8FKRF3N6F', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485Q0TDFVF3R3A0DER30RNV', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485Q2JV6Q3PDBXKZD89G89B'], 'received_at': '2022-05-29T15:07:23.612977192Z', 'join_accept': {'session_key_id': 'AYEQW4NU3czoBXXe/Jogkw==', 'received_at': '2022-05-29T15:07:21.805316638Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DDDBE'}, 'correlation_ids': ['as:up:01G485Q2JW18HTGBR8DGHEWWKP', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485Q0TC1ZC7NZBZAY38FVMQ', 'ns:uplink:01G485Q0TDGK979WH8FKRF3N6F', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485Q0TDFVF3R3A0DER30RNV', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485Q2JV6Q3PDBXKZD89G89B'], 'received_at': '2022-05-29T15:07:23.612977192Z', 'join_accept': {'session_key_id': 'AYEQW4NU3czoBXXe/Jogkw==', 'received_at': '2022-05-29T15:07:21.805316638Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D7781'}, 'correlation_ids': ['as:up:01G485QJ13GM9DSFM9DY2ENP3S', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485QG82JR61ZKK5VQ05HPCZ', 'ns:uplink:01G485QG83T12CRWVF3528CEZK', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485QG839REDWZGP1GJVDB9J', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485QJ12N02KV9VDZMK488Q3'], 'received_at': '2022-05-29T15:07:39.427241969Z', 'join_accept': {'session_key_id': 'AYEQW8EHmuld+u1r25a2cg==', 'received_at': '2022-05-29T15:07:37.603260036Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D7781'}, 'correlation_ids': ['as:up:01G485QJ13GM9DSFM9DY2ENP3S', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485QG82JR61ZKK5VQ05HPCZ', 'ns:uplink:01G485QG83T12CRWVF3528CEZK', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485QG839REDWZGP1GJVDB9J', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485QJ12N02KV9VDZMK488Q3'], 'received_at': '2022-05-29T15:07:39.427241969Z', 'join_accept': {'session_key_id': 'AYEQW8EHmuld+u1r25a2cg==', 'received_at': '2022-05-29T15:07:37.603260036Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D06DD'}, 'correlation_ids': ['as:up:01G485R1S5S9TP3M2417XX91TF', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485R00DDM2PZANNT6FGSY1J', 'ns:uplink:01G485R00EBP906ZTGVMP7ZQ0N', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485R00EH6YK4CJJGBR757T3', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485R1S4WMQ8SDQQF7SD96P7'], 'received_at': '2022-05-29T15:07:55.557460868Z', 'join_accept': {'session_key_id': 'AYEQXAAV/FqLb+rows33Tw==', 'received_at': '2022-05-29T15:07:53.742224787Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D06DD'}, 'correlation_ids': ['as:up:01G485R1S5S9TP3M2417XX91TF', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485R00DDM2PZANNT6FGSY1J', 'ns:uplink:01G485R00EBP906ZTGVMP7ZQ0N', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485R00EH6YK4CJJGBR757T3', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485R1S4WMQ8SDQQF7SD96P7'], 'received_at': '2022-05-29T15:07:55.557460868Z', 'join_accept': {'session_key_id': 'AYEQXAAV/FqLb+rows33Tw==', 'received_at': '2022-05-29T15:07:53.742224787Z'}}
# ....
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D2951'}, 'correlation_ids': ['as:up:01G485RF31F0HFND290R0FMYNZ', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485RDAEBCMVTGYZBTVM4BCZ', 'ns:uplink:01G485RDAFYT0PHCJQC3ZGG8T9', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485RDAFVVZN2V5T365FDD1Z', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485RF31TJPA6683SKA57BX4'], 'received_at': '2022-05-29T15:08:09.185585561Z', 'join_accept': {'session_key_id': 'AYEQXDVV4SR7Z6TnPSB30g==', 'received_at': '2022-05-29T15:08:07.375575398Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D2951'}, 'correlation_ids': ['as:up:01G485RF31F0HFND290R0FMYNZ', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485RDAEBCMVTGYZBTVM4BCZ', 'ns:uplink:01G485RDAFYT0PHCJQC3ZGG8T9', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485RDAFVVZN2V5T365FDD1Z', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485RF31TJPA6683SKA57BX4'], 'received_at': '2022-05-29T15:08:09.185585561Z', 'join_accept': {'session_key_id': 'AYEQXDVV4SR7Z6TnPSB30g==', 'received_at': '2022-05-29T15:08:07.375575398Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DC2B8'}, 'correlation_ids': ['as:up:01G485RY64MPZQBHPN80XEBFME', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485RWDHC6ZCKX02Z8D7P0KC', 'ns:uplink:01G485RWDJ5KVV5YQYXB7CEYZN', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485RWDJ42RZAR3GHDFQP4QE', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485RY63HQBGQ6EFHCA18EES'], 'received_at': '2022-05-29T15:08:24.644780376Z', 'join_accept': {'session_key_id': 'AYEQXHG7M4hTSJtySwVZOw==', 'received_at': '2022-05-29T15:08:22.834488148Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DC2B8'}, 'correlation_ids': ['as:up:01G485RY64MPZQBHPN80XEBFME', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485RWDHC6ZCKX02Z8D7P0KC', 'ns:uplink:01G485RWDJ5KVV5YQYXB7CEYZN', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485RWDJ42RZAR3GHDFQP4QE', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485RY63HQBGQ6EFHCA18EES'], 'received_at': '2022-05-29T15:08:24.644780376Z', 'join_accept': {'session_key_id': 'AYEQXHG7M4hTSJtySwVZOw==', 'received_at': '2022-05-29T15:08:22.834488148Z'}}
# ....
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D2E77'}, 'correlation_ids': ['as:up:01G485SXFQKNDD3NZ6NEKNG3QV', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485SVPYEYSEBWECHJH9GP20', 'ns:uplink:01G485SVPZT8K6S279VS6XZCQJ', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485SVPZSMRMTRRSCQTK0WEA', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485SXFQ4M0MRTSM87J7Y0ZG'], 'received_at': '2022-05-29T15:08:56.695907658Z', 'join_accept': {'session_key_id': 'AYEQXO7ke/msWu9dySvHaw==', 'received_at': '2022-05-29T15:08:54.879642386Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D2E77'}, 'correlation_ids': ['as:up:01G485SXFQKNDD3NZ6NEKNG3QV', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485SVPYEYSEBWECHJH9GP20', 'ns:uplink:01G485SVPZT8K6S279VS6XZCQJ', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485SVPZSMRMTRRSCQTK0WEA', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485SXFQ4M0MRTSM87J7Y0ZG'], 'received_at': '2022-05-29T15:08:56.695907658Z', 'join_accept': {'session_key_id': 'AYEQXO7ke/msWu9dySvHaw==', 'received_at': '2022-05-29T15:08:54.879642386Z'}}
# ....
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D51A7'}, 'correlation_ids': ['as:up:01G485TCS65FYJB9ZF9NTMMPTJ', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485TB0K05AZXSA27EFD9WXP', 'ns:uplink:01G485TB0M87HQ4H71PX72JH2F', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485TB0M1963EDNFE1XZ3KBB', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485TCS6GM0ABBXGBFXHM4YK'], 'received_at': '2022-05-29T15:09:12.359035891Z', 'join_accept': {'session_key_id': 'AYEQXSwZjW/8VxPvE9Eb6w==', 'received_at': '2022-05-29T15:09:10.548721825Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D51A7'}, 'correlation_ids': ['as:up:01G485TCS65FYJB9ZF9NTMMPTJ', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485TB0K05AZXSA27EFD9WXP', 'ns:uplink:01G485TB0M87HQ4H71PX72JH2F', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485TB0M1963EDNFE1XZ3KBB', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485TCS6GM0ABBXGBFXHM4YK'], 'received_at': '2022-05-29T15:09:12.359035891Z', 'join_accept': {'session_key_id': 'AYEQXSwZjW/8VxPvE9Eb6w==', 'received_at': '2022-05-29T15:09:10.548721825Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DFC3C'}, 'correlation_ids': ['as:up:01G485TWD0X5FRWYPNNFXHZC72', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485TTM8RWQ9HMK7XKB3K76J', 'ns:uplink:01G485TTM90TZ3A07KF9Y637AK', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485TTM91X0417VRR1GFR5CZ', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485TWCZ3YDXWXFB6N5WY8S4'], 'received_at': '2022-05-29T15:09:28.352947320Z', 'join_accept': {'session_key_id': 'AYEQXWqQflIkyG/HrpN5pQ==', 'received_at': '2022-05-29T15:09:26.537521466Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DFC3C'}, 'correlation_ids': ['as:up:01G485TWD0X5FRWYPNNFXHZC72', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485TTM8RWQ9HMK7XKB3K76J', 'ns:uplink:01G485TTM90TZ3A07KF9Y637AK', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485TTM91X0417VRR1GFR5CZ', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485TWCZ3YDXWXFB6N5WY8S4'], 'received_at': '2022-05-29T15:09:28.352947320Z', 'join_accept': {'session_key_id': 'AYEQXWqQflIkyG/HrpN5pQ==', 'received_at': '2022-05-29T15:09:26.537521466Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D493C'}, 'correlation_ids': ['as:up:01G485VDFE7MA56JRBG8BAKHV7', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485VBPY0XZVBD20SBXRAHEX', 'ns:uplink:01G485VBPZCMRCRPEH2G4S1Z0E', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485VBPZEFYWEA7PDSWKKW2Q', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485VDFDDDYATM3SMCVQRCVD'], 'received_at': '2022-05-29T15:09:45.838374294Z', 'join_accept': {'session_key_id': 'AYEQXa7k8/MaHvGdqXTz3w==', 'received_at': '2022-05-29T15:09:44.031783832Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D493C'}, 'correlation_ids': ['as:up:01G485VDFE7MA56JRBG8BAKHV7', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G485VBPY0XZVBD20SBXRAHEX', 'ns:uplink:01G485VBPZCMRCRPEH2G4S1Z0E', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G485VBPZEFYWEA7PDSWKKW2Q', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G485VDFDDDYATM3SMCVQRCVD'], 'received_at': '2022-05-29T15:09:45.838374294Z', 'join_accept': {'session_key_id': 'AYEQXa7k8/MaHvGdqXTz3w==', 'received_at': '2022-05-29T15:09:44.031783832Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# ...
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DD670'}, 'correlation_ids': ['as:up:01G4896G9B1FF3KAWMXP3ZZ48D', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G4896EGRMKC77ABA0DFEQZR8', 'ns:uplink:01G4896EGR0YJ9PFFB33WQVHG0', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G4896EGRYRFEJP9G328PE35H', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G4896G9AA75WQSRM5CM9WEFJ'], 'received_at': '2022-05-29T16:08:14.891763858Z', 'join_accept': {'session_key_id': 'AYEQkzodj+DsshzARPGGqA==', 'received_at': '2022-05-29T16:08:13.080689453Z'}}
# ....
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D4B38'}, 'correlation_ids': ['as:up:01G4896XD5KDB6RAZD9N5X6BXF', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G4896VHWZQ9BAXV8PJAM7J3P', 'ns:uplink:01G4896VHXQCVZ6RJ2GP54J5R0', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G4896VHXRJY9WN283X3YX9TD', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G4896XCST5ZR9D001CDHRDTA'], 'received_at': '2022-05-29T16:08:28.326135017Z', 'join_accept': {'session_key_id': 'AYEQk25CNVbZQiLPKC+NHw==', 'received_at': '2022-05-29T16:08:26.429293687Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D4B38'}, 'correlation_ids': ['as:up:01G4896XD5KDB6RAZD9N5X6BXF', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G4896VHWZQ9BAXV8PJAM7J3P', 'ns:uplink:01G4896VHXQCVZ6RJ2GP54J5R0', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G4896VHXRJY9WN283X3YX9TD', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G4896XCST5ZR9D001CDHRDTA'], 'received_at': '2022-05-29T16:08:28.326135017Z', 'join_accept': {'session_key_id': 'AYEQk25CNVbZQiLPKC+NHw==', 'received_at': '2022-05-29T16:08:26.429293687Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D7B6C'}, 'correlation_ids': ['as:up:01G4897ATP9E8Y7GQEQWWV1HJY', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G48979247KF2BJTD0WRDMDF1', 'ns:uplink:01G4897924SMNA7W4H8YYEH4HA', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G48979244ZKD2P9Y4N7Q17ZG', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G4897ATNZYZ9X5P1D743Z70C'], 'received_at': '2022-05-29T16:08:42.070180235Z', 'join_accept': {'session_key_id': 'AYEQk6RKi5R61e/ZAh5mzA==', 'received_at': '2022-05-29T16:08:40.260642255Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D7B6C'}, 'correlation_ids': ['as:up:01G4897ATP9E8Y7GQEQWWV1HJY', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G48979247KF2BJTD0WRDMDF1', 'ns:uplink:01G4897924SMNA7W4H8YYEH4HA', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G48979244ZKD2P9Y4N7Q17ZG', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G4897ATNZYZ9X5P1D743Z70C'], 'received_at': '2022-05-29T16:08:42.070180235Z', 'join_accept': {'session_key_id': 'AYEQk6RKi5R61e/ZAh5mzA==', 'received_at': '2022-05-29T16:08:40.260642255Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DAD98'}, 'correlation_ids': ['as:up:01G4897QMPDSYC6JVSN507E334', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G4897NW8YE0VT23HEQ649FBA', 'ns:uplink:01G4897NW96BPV6RP2W7FFHP26', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G4897NW88SHKS6PA715DH7HM', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G4897QMP067QGCM4PRFXWXGQ'], 'received_at': '2022-05-29T16:08:55.190959511Z', 'join_accept': {'session_key_id': 'AYEQk9eQcyXt63NsW82EUw==', 'received_at': '2022-05-29T16:08:53.385038547Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DAD98'}, 'correlation_ids': ['as:up:01G4897QMPDSYC6JVSN507E334', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G4897NW8YE0VT23HEQ649FBA', 'ns:uplink:01G4897NW96BPV6RP2W7FFHP26', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G4897NW88SHKS6PA715DH7HM', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G4897QMP067QGCM4PRFXWXGQ'], 'received_at': '2022-05-29T16:08:55.190959511Z', 'join_accept': {'session_key_id': 'AYEQk9eQcyXt63NsW82EUw==', 'received_at': '2022-05-29T16:08:53.385038547Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DFA03'}, 'correlation_ids': ['as:up:01G48987H7A1JJJTEP4PY0C6GZ', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G48985RQ097BVS61JHGZ82GG', 'ns:uplink:01G48985RR3H333BNQR4ARZ3MQ', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G48985RRM7AT7H8R94MCMVHY', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G48987H7G6HN9P41GPKG1WTH'], 'received_at': '2022-05-29T16:09:11.463662319Z', 'join_accept': {'session_key_id': 'AYEQlBcdh3lMcfb9SoEp0A==', 'received_at': '2022-05-29T16:09:09.656228295Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DFA03'}, 'correlation_ids': ['as:up:01G48987H7A1JJJTEP4PY0C6GZ', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G48985RQ097BVS61JHGZ82GG', 'ns:uplink:01G48985RR3H333BNQR4ARZ3MQ', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G48985RRM7AT7H8R94MCMVHY', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G48987H7G6HN9P41GPKG1WTH'], 'received_at': '2022-05-29T16:09:11.463662319Z', 'join_accept': {'session_key_id': 'AYEQlBcdh3lMcfb9SoEp0A==', 'received_at': '2022-05-29T16:09:09.656228295Z'}}
# ....
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D10DB'}, 'correlation_ids': ['as:up:01G4898QPBBXB5YRDDYYAVJ8RM', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G4898NXSHD926412BSAJ8GVE', 'ns:uplink:01G4898NXT7MZSW1X27TMJ10ZS', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G4898NXTN6FRFMYRF44P6YJD', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G4898QP8Q7Q3V33ESF7TNXPX'], 'received_at': '2022-05-29T16:09:28.011354981Z', 'join_accept': {'session_key_id': 'AYEQlFfCgavtlIz9kFArhw==', 'received_at': '2022-05-29T16:09:26.202425050Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D10DB'}, 'correlation_ids': ['as:up:01G4898QPBBXB5YRDDYYAVJ8RM', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G4898NXSHD926412BSAJ8GVE', 'ns:uplink:01G4898NXT7MZSW1X27TMJ10ZS', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G4898NXTN6FRFMYRF44P6YJD', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G4898QP8Q7Q3V33ESF7TNXPX'], 'received_at': '2022-05-29T16:09:28.011354981Z', 'join_accept': {'session_key_id': 'AYEQlFfCgavtlIz9kFArhw==', 'received_at': '2022-05-29T16:09:26.202425050Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D043F'}, 'correlation_ids': ['as:up:01G48996MB22HWY92V4CJ683BD', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G48994TYMT3E51S70ZMSGP88', 'ns:uplink:01G48994TZZA9KP7HYWS9MK4PF', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G48994TZCW9CDKFK7T35XNSQ', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G48996MA9Z657C6EJ807JJT5'], 'received_at': '2022-05-29T16:09:43.307348438Z', 'join_accept': {'session_key_id': 'AYEQlJNkyNpwCrQEz6hWRA==', 'received_at': '2022-05-29T16:09:41.471804849Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D043F'}, 'correlation_ids': ['as:up:01G48996MB22HWY92V4CJ683BD', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G48994TYMT3E51S70ZMSGP88', 'ns:uplink:01G48994TZZA9KP7HYWS9MK4PF', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G48994TZCW9CDKFK7T35XNSQ', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G48996MA9Z657C6EJ807JJT5'], 'received_at': '2022-05-29T16:09:43.307348438Z', 'join_accept': {'session_key_id': 'AYEQlJNkyNpwCrQEz6hWRA==', 'received_at': '2022-05-29T16:09:41.471804849Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DC179'}, 'correlation_ids': ['as:up:01G4899PBANCMYSABECP7ARB6Z', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G4899MJRX9CKJGFS4Y66SV8B', 'ns:uplink:01G4899MJS8XHH7TJFAV44EGA2', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G4899MJRF2CMA4Q5WT3GSRAT', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G4899PB99SV2FN63FP4YEQP8'], 'received_at': '2022-05-29T16:09:59.402865421Z', 'join_accept': {'session_key_id': 'AYEQlNJdfnbB5wD3vwOXDg==', 'received_at': '2022-05-29T16:09:57.593065756Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260DC179'}, 'correlation_ids': ['as:up:01G4899PBANCMYSABECP7ARB6Z', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G4899MJRX9CKJGFS4Y66SV8B', 'ns:uplink:01G4899MJS8XHH7TJFAV44EGA2', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G4899MJRF2CMA4Q5WT3GSRAT', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G4899PB99SV2FN63FP4YEQP8'], 'received_at': '2022-05-29T16:09:59.402865421Z', 'join_accept': {'session_key_id': 'AYEQlNJdfnbB5wD3vwOXDg==', 'received_at': '2022-05-29T16:09:57.593065756Z'}}
# ..
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D63FB'}, 'correlation_ids': ['as:up:01G489A43DST2M0HC4H33K844R', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G489A2AVV72XBZF3VKSH14FZ', 'ns:uplink:01G489A2AVMPDEAWJPRWECRTFT', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G489A2AVEG6Y3SJW8HN0XMWC', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G489A43DD6ZBNA0PV6J2BJ6K'], 'received_at': '2022-05-29T16:10:13.485658200Z', 'join_accept': {'session_key_id': 'AYEQlQlhUENDFbBeIKMv+g==', 'received_at': '2022-05-29T16:10:11.675911507Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D63FB'}, 'correlation_ids': ['as:up:01G489A43DST2M0HC4H33K844R', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G489A2AVV72XBZF3VKSH14FZ', 'ns:uplink:01G489A2AVMPDEAWJPRWECRTFT', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G489A2AVEG6Y3SJW8HN0XMWC', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G489A43DD6ZBNA0PV6J2BJ6K'], 'received_at': '2022-05-29T16:10:13.485658200Z', 'join_accept': {'session_key_id': 'AYEQlQlhUENDFbBeIKMv+g==', 'received_at': '2022-05-29T16:10:11.675911507Z'}}
# ....
# Message: v3/app-tcc-tolerancia-a-falhas@ttn/devices/ttgo-app-tolerante-a-falhas/join 0
# Payload:  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D59A9'}, 'correlation_ids': ['as:up:01G489AJADCVAYNAJ9BGRVCWPB', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G489AGHX9TZ63D2SPAP7TRAP', 'ns:uplink:01G489AGHY1XHMJCFZ9A4W74KB', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G489AGHX4QZ29AD5TN6X1D9Z', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G489AJAC7XQDT5D14D0WYMZE'], 'received_at': '2022-05-29T16:10:28.045188481Z', 'join_accept': {'session_key_id': 'AYEQlUJCz7PtI3oMrIb8Bw==', 'received_at': '2022-05-29T16:10:26.238119695Z'}}
# -- ALR LORAWAN  {'end_device_ids': {'device_id': 'ttgo-app-tolerante-a-falhas', 'application_ids': {'application_id': 'app-tcc-tolerancia-a-falhas'}, 'dev_eui': '70B3D57ED00475AE', 'join_eui': '0000000000000000', 'dev_addr': '260D59A9'}, 'correlation_ids': ['as:up:01G489AJADCVAYNAJ9BGRVCWPB', 'gs:conn:01G3R44RNN6K8Z5WKHHH8X6N2A', 'gs:up:host:01G3R44RYF8YHZXKHY31EPGDE6', 'gs:uplink:01G489AGHX9TZ63D2SPAP7TRAP', 'ns:uplink:01G489AGHY1XHMJCFZ9A4W74KB', 'rpc:/ttn.lorawan.v3.GsNs/HandleUplink:01G489AGHX4QZ29AD5TN6X1D9Z', 'rpc:/ttn.lorawan.v3.NsAs/HandleUplink:01G489AJAC7XQDT5D14D0WYMZE'], 'received_at': '2022-05-29T16:10:28.045188481Z', 'join_accept': {'session_key_id': 'AYEQlUJCz7PtI3oMrIb8Bw==', 'received_at': '2022-05-29T16:10:26.238119695Z'}}
# .Exit
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
